# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# import matplotlib

# %%
import matplotlib

# %%
Total_N = []
Total_V = []

with open('/Users/XIAN/Documents/xian fyp/duplicate.txt', 'r+') as f:
    for line in f.readlines():
        N = float(line.strip('\n')) * 27.211
        Total_N = np.append(Total_N,N)
        
with open('/Users/XIAN/Documents/xian fyp/duplicate3.txt', 'r+') as f:
    for line in f.readlines():
        Value = float(line.strip('\n'))*27.211
        Total_V = np.append(Total_V,Value)

# %%
print(Total_V)
# Out:
# [3.6163419 3.6054575 2.7347055 ... 4.6367544 4.2830114 4.3347123]

# %%
plt.figure(figsize=(10,10))

plt.plot(Total_V,Total_N,'o',markersize=1)
plt.xlabel('prediction')
plt.ylabel('actual value')
plt.title('actual value against prediction')
# Out:
# Text(0.5, 1.0, 'actual value against prediction')

# %%
print(np.arange(-0.35, 0, step=0.025))
# Out:
# [-0.35  -0.325 -0.3   -0.275 -0.25  -0.225 -0.2   -0.175 -0.15  -0.125
#  -0.1   -0.075 -0.05  -0.025]

# %%
data = np.concatenate((Total_N, Total_V))
plt.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2034b2f1898>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2034b2f1f28>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2034b2f1470>],
#  'medians': [<matplotlib.lines.Line2D at 0x2034b2fb5f8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2034b2fb940>],
#  'means': []}

# %%
df.boxplot(column='LUMO', by='Total Number of N',figsize = (5,5))
plt.ylabel('LUMO, eV')
plt.savefig('LUMO')

# %%
df.boxplot(column='HOMO' ,by='Total Number of N',figsize = (5,5))
plt.ylabel('HOMO, eV')
df.boxplot(column='LUMO' ,by='Total Number of N',figsize = (5,5))
matplotlib.ticker.EngFormatter(places=3)
plt.ylabel('LUMO, eV')


plt.savefig('HOMO LUMO')

# %%
df = pd.read_excel('/Users/XIAN/Documents/xian fyp/Only CN.xlsx')

# %%
df.boxplot(column='Band Gap', by='Total Number of N',figsize = (5,5))
plt.ylabel('Band Gap, eV')
plt.savefig('Band Gap.png')
